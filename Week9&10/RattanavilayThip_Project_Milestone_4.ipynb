# %% [markdown]
# ##########################################################
# #### File: RattanavilayThip_Project_Milestone_4<br>
# #### Name: Thip Rattanavilay<br>
# #### Date: 05/23/2021<br>
# #### Course: DSC 540 - Assignment: Project: Milestone 4<br>
# ##########################################################

# %%
#import libraries
import urllib.request, urllib.parse, urllib.error
import requests
from bs4 import BeautifulSoup
import ssl
import re
import json
import matplotlib.pyplot as plt

# %% [markdown]
# # Connecting to an API/Pulling in the Data and Cleaning/Formatting

# %%
#called the api from api.covid19api.com
api_url = "https://api.covid19api.com/summary"
headers = {'Content-Type': 'application/json'}
response = requests.get(api_url, headers=headers)
response_json = response.json()

# %%
#Created a variable that would read the json specifically using countries
countries = (response_json['Countries'])

# %%
#Created the dataframe
df = pd.DataFrame(countries)
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan           658           11831
# 1           Albania          AL         albania            25            1029
# 2           Algeria          DZ         algeria           194            8697
# 3           Andorra          AD         andorra             0             763
# 4            Angola          AO          angola             0              70
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         vietnam             1             327
# 182  Western Sahara          EH  western-sahara             0               9
# 183           Yemen          YE           yemen            16             249
# 184          Zambia          ZM          zambia             0             920
# 185        Zimbabwe          ZW        zimbabwe             0              56
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            1          220            31            1128
# 1            1           33             8             803
# 2            8          617           171            4918
# 3            0           51            13             676
# 4            0            4             0              18
# ..         ...          ...           ...             ...
# 181          0            0             0             272
# 182          1            1             0               6
# 183          5           49             0              10
# 184          0            7             0             336
# 185          0            4             0              25
#
#                      Date
# 0    2020-05-27T22:46:52Z
# 1    2020-05-27T22:46:52Z
# 2    2020-05-27T22:46:52Z
# 3    2020-05-27T22:46:52Z
# 4    2020-05-27T22:46:52Z
# ..                    ...
# 181  2020-05-27T22:46:52Z
# 182  2020-05-27T22:46:52Z
# 183  2020-05-27T22:46:52Z
# 184  2020-05-27T22:46:52Z
# 185  2020-05-27T22:46:52Z
#
# [186 rows x 10 columns]

# %%
#Slug has everything in lowercase as those are proper nouns so I'm going to capitalize the first letter 
df['Slug'] = df['Slug'].str.capitalize()   
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     Afghanistan           658           11831
# 1           Albania          AL         Albania            25            1029
# 2           Algeria          DZ         Algeria           194            8697
# 3           Andorra          AD         Andorra             0             763
# 4            Angola          AO          Angola             0              70
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         Vietnam             1             327
# 182  Western Sahara          EH  Western-sahara             0               9
# 183           Yemen          YE           Yemen            16             249
# 184          Zambia          ZM          Zambia             0             920
# 185        Zimbabwe          ZW        Zimbabwe             0              56
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            1          220            31            1128
# 1            1           33             8             803
# 2            8          617           171            4918
# 3            0           51            13             676
# 4            0            4             0              18
# ..         ...          ...           ...             ...
# 181          0            0             0             272
# 182          1            1             0               6
# 183          5           49             0              10
# 184          0            7             0             336
# 185          0            4             0              25
#
#                      Date
# 0    2020-05-27T22:46:52Z
# 1    2020-05-27T22:46:52Z
# 2    2020-05-27T22:46:52Z
# 3    2020-05-27T22:46:52Z
# 4    2020-05-27T22:46:52Z
# ..                    ...
# 181  2020-05-27T22:46:52Z
# 182  2020-05-27T22:46:52Z
# 183  2020-05-27T22:46:52Z
# 184  2020-05-27T22:46:52Z
# 185  2020-05-27T22:46:52Z
#
# [186 rows x 10 columns]

# %%
#Want to split up the date/time column into separate columns one for date and one for time
df['Dates'] = pd.to_datetime(df['Date']).dt.date
df['Time'] = pd.to_datetime(df['Date']).dt.time
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     Afghanistan           658           11831
# 1           Albania          AL         Albania            25            1029
# 2           Algeria          DZ         Algeria           194            8697
# 3           Andorra          AD         Andorra             0             763
# 4            Angola          AO          Angola             0              70
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         Vietnam             1             327
# 182  Western Sahara          EH  Western-sahara             0               9
# 183           Yemen          YE           Yemen            16             249
# 184          Zambia          ZM          Zambia             0             920
# 185        Zimbabwe          ZW        Zimbabwe             0              56
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            1          220            31            1128
# 1            1           33             8             803
# 2            8          617           171            4918
# 3            0           51            13             676
# 4            0            4             0              18
# ..         ...          ...           ...             ...
# 181          0            0             0             272
# 182          1            1             0               6
# 183          5           49             0              10
# 184          0            7             0             336
# 185          0            4             0              25
#
#                      Date       Dates      Time
# 0    2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 1    2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 2    2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 3    2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 4    2020-05-27T22:46:52Z  2020-05-27  22:46:52
# ..                    ...         ...       ...
# 181  2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 182  2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 183  2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 184  2020-05-27T22:46:52Z  2020-05-27  22:46:52
# 185  2020-05-27T22:46:52Z  2020-05-27  22:46:52
#
# [186 rows x 12 columns]

# %%
#Now I can drop the original column Date
df.drop(columns=['Date'])
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     Afghanistan           658           11831
# 1           Albania          AL         Albania            25            1029
# 2           Algeria          DZ         Algeria           194            8697
# 3           Andorra          AD         Andorra             0             763
# 4            Angola          AO          Angola             0              70
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         Vietnam             1             327
# 182  Western Sahara          EH  Western-sahara             0               9
# 183           Yemen          YE           Yemen            16             249
# 184          Zambia          ZM          Zambia             0             920
# 185        Zimbabwe          ZW        Zimbabwe             0              56
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered       Dates  \
# 0            1          220            31            1128  2020-05-27
# 1            1           33             8             803  2020-05-27
# 2            8          617           171            4918  2020-05-27
# 3            0           51            13             676  2020-05-27
# 4            0            4             0              18  2020-05-27
# ..         ...          ...           ...             ...         ...
# 181          0            0             0             272  2020-05-27
# 182          1            1             0               6  2020-05-27
# 183          5           49             0              10  2020-05-27
# 184          0            7             0             336  2020-05-27
# 185          0            4             0              25  2020-05-27
#
#          Time
# 0    22:46:52
# 1    22:46:52
# 2    22:46:52
# 3    22:46:52
# 4    22:46:52
# ..        ...
# 181  22:46:52
# 182  22:46:52
# 183  22:46:52
# 184  22:46:52
# 185  22:46:52
#
# [186 rows x 11 columns]

# %%
df.to_csv('covid_clean_data3.csv')
