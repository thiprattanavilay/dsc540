# %% [markdown]
# ##########################################################
# #### File: RattanavilayThip_Weeks_3_&_4_Exercises<br>
# #### Name: Thip Rattanavilay<br>
# #### Date: 04/8/2021<br>
# #### Course: DSC 540 - Weeks 3 & 4 Exercises<br>
# ##########################################################

# %% [markdown]
# ## Activity 5: Generating Statistics from a CSV File
# Suppose you are working with the famous Boston housing price (from 1960) dataset. This dataset is famous in the machine learning community. Many regression problems can be formulated, and machine learning algorithms can be run on this dataset. You will perform a basic data wrangling activity (including plotting some trends) on this dataset by reading it as a pandas DataFrame.

# %% [markdown]
# 1. **Load the necessary libraries**

# %%
# Loading libraries
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html
from sklearn.datasets import load_boston 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. **Read in the Boston housing dataset (given as .csv file) from the local directory.**

# %%
# sklearn has the boston dataset available as a test dataset. Using sklearn.datasets for this exercise
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html

boston_data = load_boston()

# %%
# Use pandas to read and creating the dataframe
df = pd.DataFrame(boston_data['data'], columns=boston_data['feature_names'])
df['MEDV'] = pd.Series(boston_data['target'])
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
# Saving the dataset to CSV to align with the exercise requirements

df.to_csv("Boston_Housing_Prices.csv", index=False)
df = pd.read_csv("Boston_Housing_Prices.csv")

# %% [markdown]
# 3. **Check the first 10 records. Find the total number of records**

# %%
# Use the head method to view the first 10 records

df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
# Print the total number of records using the len function

len(df)
# Out:
# 506

# %% [markdown]
# 4. **Create a smaller DataFrame with columns that do not include `CHAS`, `NOX`, `B`, and `LSTAT`.**

# %%
# Create new dataframe without the CHAS, NOX, B, AND LSTAT columns by using the drop method to drop the columns
# i don't want in the new dataframe

df2 = df.drop(['CHAS', 'NOX', 'B', 'LSTAT'], axis = 1).copy()
df2.head()
# Out:
#       CRIM    ZN  INDUS     RM   AGE     DIS  RAD    TAX  PTRATIO  MEDV
# 0  0.00632  18.0   2.31  6.575  65.2  4.0900  1.0  296.0     15.3  24.0
# 1  0.02731   0.0   7.07  6.421  78.9  4.9671  2.0  242.0     17.8  21.6
# 2  0.02729   0.0   7.07  7.185  61.1  4.9671  2.0  242.0     17.8  34.7
# 3  0.03237   0.0   2.18  6.998  45.8  6.0622  3.0  222.0     18.7  33.4
# 4  0.06905   0.0   2.18  7.147  54.2  6.0622  3.0  222.0     18.7  36.2

# %% [markdown]
# 5. **Check the last seven records of the new DataFrame you just created.**

# %%
# View the last 7 records of the new data frame and verify that the columns were dropped

df2.tail(7)
# Out:
#         CRIM   ZN  INDUS     RM   AGE     DIS  RAD    TAX  PTRATIO  MEDV
# 499  0.17783  0.0   9.69  5.569  73.5  2.3999  6.0  391.0     19.2  17.5
# 500  0.22438  0.0   9.69  6.027  79.7  2.4982  6.0  391.0     19.2  16.8
# 501  0.06263  0.0  11.93  6.593  69.1  2.4786  1.0  273.0     21.0  22.4
# 502  0.04527  0.0  11.93  6.120  76.7  2.2875  1.0  273.0     21.0  20.6
# 503  0.06076  0.0  11.93  6.976  91.0  2.1675  1.0  273.0     21.0  23.9
# 504  0.10959  0.0  11.93  6.794  89.3  2.3889  1.0  273.0     21.0  22.0
# 505  0.04741  0.0  11.93  6.030  80.8  2.5050  1.0  273.0     21.0  11.9

# %% [markdown]
# 6. **Plot the histogram of all the variables (columns) in the new DataFrame.**

# %%
# Plot histograms for df2.

df2.plot.hist(bins = 50, histtype = "step", figsize=(16,9));
plt.title("Histogram")
plt.show()

# %% [markdown]
# 7. **Plot them all at once using a `for` loop. Try to add a unique title to a plot.**

# %%
# Plot separate histograms for each column in df2. I'm going to try to run this all in one code block.

for ind, i in enumerate(df2.columns):
    color = ["red","orange","yellow","green","blue","cyan","purple","magenta","black","grey"][ind]
    plt.figure(figsize = (10,5))
    plt.hist(df2[i], bins = 50, color = color)
    plt.title(i.upper()+" Histogram")
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.grid(True)
    plt.show()

# %% [markdown]
# 8. **Create a scatter plot of crime rate versus price.**

# %%
# To create a scatterplot of crime rate vs price, I used some of the customized graphics properties that were demonstrated
# in our reading.

plt.figure(figsize = (16,9))
plt.scatter(df2['CRIM'], df2['MEDV'], color = "black")
plt.title("Crime Rate vs Price")
plt.xlabel("CRIM")
plt.ylabel("MENV")
plt.grid(True)
plt.show()

# %% [markdown]
# 9. **Plot using `log10(crime)` verses price.**

# %%
# To create a scatterplot of Log crim vs price, I used some of the customized graphics properties that were demonstrated
# in our reading.

plt.figure(figsize = (16,9))
plt.scatter(np.log10(df2['CRIM']), df2['MEDV'], color = "black")
plt.title("Log Crime Rate vs Price")
plt.xlabel("log(CRIM)")
plt.ylabel("MENV")
plt.grid(True)
plt.show()

# %% [markdown]
# 10. **Calculate some useful statistics, such as mean rooms per dwelling, median age, mean distance to five Boston employment centers, and the percentage of houses with a low price (<$20,000)**

# %%
mean_rooms = np.mean(df2['RM'])
print("Mean rooms per dwelling: {:.2f}".format(mean_rooms))
# Out:
# Mean rooms per dwelling: 6.28

# %%
median_age = np.median(df2['AGE'])
print("Median age: {:.1f}".format(median_age))
# Out:
# Median age: 77.5

# %%
mean_distance = np.mean(df2['DIS'])
print("Mean distance to five Boston unemployment centers: {:.2f}".format(mean_distance))
# Out:
# Mean distance to five Boston unemployment centers: 3.80

# %%
houses_under_20 = len(df2[df2['MEDV'] <20]) / len(df2)
print("Percentage of houses with a low price (<$20,000): {:.2f}%".format(houses_under_20 * 100))
# Out:
# Percentage of houses with a low price (<$20,000): 41.50%

# %% [markdown]
# ## Activity 6: Working with the Adult Income Dataset (UCI)
# In this activity, you will work with the Adult Income Dataset from the UCI machine learning portal. The Adult Income dataset has been use in many machine learning papers that address classification problems. You will read the data from a CSV file into a pandas DataFrame and do some practice on the advanced data wrangling you learned about in this chapter.
#
# THe aim of this activity is to practice various abvdanced pandas DataFrame operations, for example, for subsetting, applying user-defined functions, summary statistics, visualizations, boolean indexing, group by, and outlier detection on a real-life dataset. We have the data downloaded as CSV file on the disk for your case. However, it is recommended to practice data downloading on your own so that you are familiar with the process.
#
# Here is the URL for the dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
#
# Here is the URL for the description of the dataset and the variables: https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names
#
# These are the steps that will help you solve this activity.

# %% [markdown]
# ### Manipulating the data from UCI

# %% [markdown]
# **Load in the `adult.data` dataset into pandas**

# %%
#Load in the adult.data dataset into pandas
pd.read_table("adult.data", sep=",")
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %% [markdown]
# **Generate a list of attributes names using the `adult.names` files**

# %%
# This is an absolute mess but this .names file forced my hand

my_list = []
with open("adult.names", "r") as f:
    for line in f:
        if line[0] != "|":
            x = line.split(":")
            if x[0] != "\n":
                my_list.append(x[0])
                
my_list = [i for i in my_list if i]
my_list = my_list[1:]
print(my_list)
# Out:
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country']

# %% [markdown]
# **Add income to the list of attributes names**

# %%
# Now that I have a list of column names, I have to add an additional column name of Income to the list

my_list.append("Income")
my_list
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'Income']

# %% [markdown]
# **Combine the two to form a dataframe with the correctly labeled columns**

# %%
# I will read in the file again, but this time add the list of column names and check it with head
# I need to find the missing values. I will observe them using the na_values=' ?' function.

adult = pd.read_table("adult.data", sep=",",names=my_list, na_values=' ?')
adult
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### Using the book's method

# %% [markdown]
# 1. **Load the necessary libraries**

# %%
# Load the necessary libraries

import pandas as pd
import numpy as np

# %% [markdown]
# 2. **Read the audlt income dataset from the following URL:** https://raw.githubusercontent.com/TrainingByPackt/Data-Wrangling-with-Python/master/Chapter04/Activity06/adult_income_data.csv

# %%
# Using Pandas to read CSV file
df = pd.read_csv("adult_income_data.csv")
df
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family     Male   2174  0  40  \
# ...

# %% [markdown]
# 3. **Create a script that will read a text file line by line.** <br>_addendum_: Create a list of attribute names by reading each line of the text file (MH)

# %%
col_names = []
with open('adult_income_names.txt',"r") as f:
    for line in f:
        line = line.replace("\n", " ")
        x = line.split(": ")[0]
        if x != " ":
            col_names.append(x)
print(col_names)
# Out:
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country']

# %% [markdown]
# 4. **Add a name of `Income` for the response variable to the dataset.**<br> _addendum_: Add income to the list of attributes and assign the column names to the dataframe (MH)

# %%
# Add a name of Income for the response variable to the dataset.
col_names.append("Income")

# %%
# Using Pandas to read CSV file
df = pd.read_csv("adult_income_data.csv", names=col_names, na_values=' ?')
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship     race   sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male  2174
# 1   Married-civ-spouse     Exec-managerial         Husband     Male     0
# 2             Divorced   Handlers-cleaners   Not-in-family     Male     0
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male     0
# 4   Married-civ-spouse      Prof-specialty            Wife   Female     0
#
#    capital-gain  capital-loss  hours-per-week native-country  Income
# 0             0            40   United-States          <=50K     NaN
# ...

# %% [markdown]
# 5. **Find the missing values**

# %%
df1 = adult[adult.isna().any(axis=1)]
df1
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 14      40   Private  121772      Assoc-voc             11
# 27      54       NaN  180211   Some-college             10
# 38      31   Private   84154   Some-college             10
# 51      18   Private  226956        HS-grad              9
# 61      32       NaN  293936        7th-8th              4
# ...    ...       ...     ...            ...            ...
# 32530   35       NaN  320084      Bachelors             13
# 32531   30       NaN   33811      Bachelors             13
# 32539   71       NaN  287372      Doctorate             16
# 32541   41       NaN  202822        HS-grad              9
# 32542   72       NaN  129912        HS-grad              9
#
#                marital-status      occupation    relationship  \
# 14         Married-civ-spouse    Craft-repair         Husband
# 27         Married-civ-spouse             NaN         Husband
# 38         Married-civ-spouse           Sales         Husband
# ...

# %%
# Import matrix
import missingno as msno 
msno.matrix(adult);

# %% [markdown]
# 6. **Create a DataFrame with only age, education, and occupation by using subsetting.**

# %%
# Create a DataFrame with only age, education, and occupation by using subsetting

df2 = adult.loc[[i for i in range(len(adult))],['age','education','occupation']]

# %%
df2
# Out:
#        age    education          occupation
# 0       39    Bachelors        Adm-clerical
# 1       50    Bachelors     Exec-managerial
# 2       38      HS-grad   Handlers-cleaners
# 3       53         11th   Handlers-cleaners
# 4       28    Bachelors      Prof-specialty
# ...    ...          ...                 ...
# 32556   27   Assoc-acdm        Tech-support
# 32557   40      HS-grad   Machine-op-inspct
# 32558   58      HS-grad        Adm-clerical
# 32559   22      HS-grad        Adm-clerical
# 32560   52      HS-grad     Exec-managerial
#
# [32561 rows x 3 columns]

# %% [markdown]
# 7. **Plot a histogram of age with a bin size of 20**

# %%
# Plot a histogram of age with a bin size of 20

adult['age'].plot.hist(bins = 20);

# %% [markdown]
# 8. **Create a fiunction to strip whitespace characters.**

# %%
# Create a fiunction to strip whitespace characters.

def stripper(x):
    '''Removes whitespaces from a string'''
    return str(x).strip()

# %%
stripper("           hello            ")
# Out:
# 'hello'

# %% [markdown]
# 9. **Use the `apply` method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column**

# %%
# Use the apply method to apply this function to all the columns with string values, 
# create a new column, copy the values from this new column to the old column, and drop the new column

df2['education_clean'] = df2['education'].apply(stripper)
df2['occupation_clean'] = df2['occupation'].apply(stripper)

df2['education'] = df2['education_clean']
df2['occupation'] = df2['occupation_clean']

df2 = df2.drop(labels=['education_clean', 'occupation_clean'], axis = 1)
df2
# Out:
#        age   education         occupation
# 0       39   Bachelors       Adm-clerical
# 1       50   Bachelors    Exec-managerial
# 2       38     HS-grad  Handlers-cleaners
# 3       53        11th  Handlers-cleaners
# 4       28   Bachelors     Prof-specialty
# ...    ...         ...                ...
# 32556   27  Assoc-acdm       Tech-support
# 32557   40     HS-grad  Machine-op-inspct
# 32558   58     HS-grad       Adm-clerical
# 32559   22     HS-grad       Adm-clerical
# 32560   52     HS-grad    Exec-managerial
#
# [32561 rows x 3 columns]

# %% [markdown]
# 10. **Find the numer of people who are aged between 30 ad 50**

# %%
# Find how many people are between 30-50 years of age, by subsetting that data and counting how many records were subset.

df3 = df2[(df2['age'] >= 30) & (df2['age'] <= 50)]

# %%
print("The number of people who are aged between 30 and 50 in this dataset is {}.".format(len(df3)))
# Out:
# The number of people who are aged between 30 and 50 in this dataset is 16390.

# %% [markdown]
# 11. **Group the records based on age and education to find how the mean age is distributed.** <br> _addendum_: Group the records based by education and find the mean age for each group (MH)

# %%
print(df.groupby(['education']).describe()['age']['mean'].sort_values(ascending=False));
df.groupby(['education']).describe()['age']['mean'].sort_values(ascending=True).plot(kind="barh");
# Out:
# education
#  7th-8th         48.445820
#  Doctorate       47.702179
#  1st-4th         46.142857
#  Prof-school     44.746528
#  Masters         44.049913
#  5th-6th         42.885886
#  Preschool       42.764706
#  9th             41.060311
#  HS-grad         38.974479
#  Bachelors       38.904949
#  Assoc-voc       38.553546
#  10th            37.429796
#  Assoc-acdm      37.381443
#  Some-college    35.756275
#  11th            32.355745
#  12th            32.000000
# Name: mean, dtype: float64

# %% [markdown]
# 12. **Group by occupation and show the summary statistic of age.**

# %%
df5 = df2.groupby("occupation").describe()['age']
df5
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# Protective-serv     649.0  38.953775  12.822062  17.0  29.0  36.0  47.0  90.0
# ...

# %% [markdown]
# **Find which profession has the oldest workers on average and which profession has the largest share of the workforce above the 75th percentile.**

# %%
# Find which profession has the oldest workers on average and which profession has the largest share of 
# the workforce above the 75th percentile.


oldest_workers = df5[df5['mean'] == max(df5['mean'])]

print("The profession with the oldest worker on average is {} with an average age of {:.2f}".format(oldest_workers.index[0], oldest_workers['mean'][0]))
# Out:
# The profession with the oldest worker on average is Exec-managerial with an average age of 42.17

# %%
# The profession with the oldest worker on average is Exec-managerial with an average age of 42.17

df6 = df2[df2['age'] > np.percentile(df2['age'],75)].groupby("occupation").describe()['age']
workforce_75th = df6[df6['count'] == max(df6['count'])]

print("The profession with the largest share of workers in the 75th percentile of age is {} with a count of {:.0f} workers".format(workforce_75th.index[0], workforce_75th['count'][0]))
# Out:
# The profession with the largest share of workers in the 75th percentile of age is Exec-managerial with a count of 1165 workers

# %% [markdown]
# 13. **Use subplot and groupby to find outliers.**

# %%
# Use subplot and groupby to find outliers.

df5 = df2.groupby("occupation").describe()['age']
df5
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# Protective-serv     649.0  38.953775  12.822062  17.0  29.0  36.0  47.0  90.0
# ...

# %% [markdown]
# The Armed-Forces group is an outlier that only has 9 entries.

# %% [markdown]
# 14. **Plot the values on a bar chart**

# %%
# Plot the values on a bar chart
plt.figure(figsize=(16,9))
df5['count'].sort_values(ascending=False).plot(kind="bar");

# %% [markdown]
# 15. **Merge the data using common keys**

# %%
# Merging dataframes by concat

subset1 = df2.sample(5)
subset2 = df2.sample(5)

pd.concat([subset1,subset2])
# Out:
#        age     education         occupation
# 26225   19       HS-grad                nan
# 2011    23  Some-college      Other-service
# 21343   79     Bachelors              Sales
# 31837   31    Assoc-acdm     Prof-specialty
# 24404   17          10th      Other-service
# 13945   47     Assoc-voc     Prof-specialty
# 17285   29  Some-college  Machine-op-inspct
# 29480   24       HS-grad                nan
# 30034   59     Assoc-voc     Prof-specialty
# 31582   22    Assoc-acdm       Adm-clerical

# %%
# Merging dataframes with merge

subset3 = df[['age','education','occupation']].sample(10,random_state=540)
subset4 = df[['relationship','sex','Income']].sample(10,random_state=540)
subset3
# Out:
#        age     education          occupation
# 6165    51       HS-grad    Transport-moving
# 30222   38     Bachelors        Tech-support
# 20933   59          10th   Handlers-cleaners
# 2661    39       HS-grad        Craft-repair
# 21512   32     Bachelors               Sales
# 28158   23       HS-grad   Machine-op-inspct
# 24220   40   Prof-school      Prof-specialty
# 12296   24    Assoc-acdm        Craft-repair
# 2108    58       HS-grad     Farming-fishing
# 30083   51       HS-grad      Prof-specialty

# %%
subset4
# Out:
#           relationship      sex  Income
# 6165           Husband     Male   <=50K
# 30222   Other-relative     Male   <=50K
# 20933          Husband     Male   <=50K
# 2661           Husband     Male   <=50K
# 21512          Husband     Male    >50K
# 28158        Own-child   Female   <=50K
# 24220             Wife   Female    >50K
# 12296        Own-child     Male   <=50K
# 2108           Husband     Male   <=50K
# 30083        Unmarried     Male   <=50K

# %%
# Now i'm going to merge these two subsets using a common key and conducting an  merge, so that all the data from 
# the two will be included, not just the overlapping data, and also I am going to drop any duplicates.
subset3.merge(subset4, how='outer', left_index=True, right_index=True)
# Out:
#        age     education          occupation     relationship      sex  Income
# 6165    51       HS-grad    Transport-moving          Husband     Male   <=50K
# 30222   38     Bachelors        Tech-support   Other-relative     Male   <=50K
# 20933   59          10th   Handlers-cleaners          Husband     Male   <=50K
# 2661    39       HS-grad        Craft-repair          Husband     Male   <=50K
# 21512   32     Bachelors               Sales          Husband     Male    >50K
# 28158   23       HS-grad   Machine-op-inspct        Own-child   Female   <=50K
# 24220   40   Prof-school      Prof-specialty             Wife   Female    >50K
# 12296   24    Assoc-acdm        Craft-repair        Own-child     Male   <=50K
# 2108    58       HS-grad     Farming-fishing          Husband     Male   <=50K
# 30083   51       HS-grad      Prof-specialty        Unmarried     Male   <=50K

# %% [markdown]
# ## Exercise 3
# Create a series and practice basic arithmetic steps

# %% [markdown]
# a. **Series 1 = 7.3, -2.5, 3.4, 1.5  with  Index = ‘a’, ‘c’, ‘d’, ‘e’**

# %%
# Use pandas to create a pandas series with an index that identifies each data point with a label, then view the series.

series1 = pd.Series([7.3, -2.5, 3.4, 1.5], index = ['a','b','c','d'])

# %%
series1
# Out:
# a    7.3
# b   -2.5
# c    3.4
# d    1.5
# dtype: float64

# %% [markdown]
# b. **Series 2 = -2.1, 3.6, -1.5, 4, 3.1 with Index = ‘a’, ‘c’, ‘e’, ‘f’, ‘g’**

# %%
# Use pandas again to create another series with an index.

series2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index = ['a','c','e','f','g'])

# %%
series2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# c. **Add Series 1 and Series 2 together and print the results**

# %%
# Create a new variable that is the two series added together and view the new series.

series1 + series2
# Out:
# a    5.2
# b    NaN
# c    7.0
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# d. **Subtract Series 1 from Series 2 and print the results**

# %%
# Create a new variable that is series2 subtracted from series1 and view the new series.

series2-series1
# Out:
# a   -9.4
# b    NaN
# c    0.2
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# dtype: float64
